# %%
import pandas as pd
from evidently.dashboard import Dashboard
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from evidently.dashboard import Dashboard
#
# ModuleNotFoundError: No module named 'evidently.dashboard'

# %%
from evidently.report import Report
Report?
# Out:
# Init signature:
# Report(
#     metrics: List[Union[evidently.base_metric.Metric, evidently.metric_preset.metric_preset.MetricPreset, evidently.utils.generators.BaseGenerator]],
#     options: Union[evidently.options.base.Options, dict, List[evidently.options.option.Option], NoneType] = None,
#     timestamp: Optional[datetime.datetime] = None,
#     id: uuid.UUID = None,
#     metadata: Dict[str, Union[str, Dict[str, str], List[str]]] = None,
#     tags: List[str] = None,
#     model_id: str = None,
#     reference_id: str = None,
#     batch_size: str = None,
#     dataset_id: str = None,
#     name: str = None,
# )
# Docstring:
# Helper class that provides a standard way to create an ABC using
# inheritance.
# File:           c:\users\risha\anaconda3\lib\site-packages\evidently\report\report.py
# Type:           ABCMeta
# Subclasses:

# %%
from evidently.report import Report
help(Report)
# Out:
# Help on class Report in module evidently.report.report:
#
# class Report(evidently.suite.base_suite.ReportBase)
#  |  Report(metrics: List[Union[evidently.base_metric.Metric, evidently.metric_preset.metric_preset.MetricPreset, evidently.utils.generators.BaseGenerator]], options: Union[evidently.options.base.Options, dict, List[evidently.options.option.Option], NoneType] = None, timestamp: Optional[datetime.datetime] = None, id: uuid.UUID = None, metadata: Dict[str, Union[str, Dict[str, str], List[str]]] = None, tags: List[str] = None, model_id: str = None, reference_id: str = None, batch_size: str = None, dataset_id: str = None, name: str = None)
#  |
#  |  Method resolution order:
#  |      Report
#  |      evidently.suite.base_suite.ReportBase
#  |      evidently.suite.base_suite.Display
#  |      evidently.suite.base_suite.Runnable
#  |      abc.ABC
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, metrics: List[Union[evidently.base_metric.Metric, evidently.metric_preset.metric_preset.MetricPreset, evidently.utils.generators.BaseGenerator]], options: Union[evidently.options.base.Options, dict, List[evidently.options.option.Option], NoneType] = None, timestamp: Optional[datetime.datetime] = None, id: uuid.UUID = None, metadata: Dict[str, Union[str, Dict[str, str], List[str]]] = None, tags: List[str] = None, model_id: str = None, reference_id: str = None, batch_size: str = None, dataset_id: str = None, name: str = None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  as_dataframe(self, group: str = None) -> Union[Dict[str, pandas.core.frame.DataFrame], pandas.core.frame.DataFrame]
#  |
#  |  as_dict(self, include_render: bool = False, include: Dict[str, Union[ForwardRef('AbstractSetIntStr'), ForwardRef('MappingIntStrAny')]] = None, exclude: Dict[str, Union[ForwardRef('AbstractSetIntStr'), ForwardRef('MappingIntStrAny')]] = None, **kwargs) -> dict
#  |
#  |  run(self, *, reference_data, current_data, column_mapping: Optional[evidently.pipeline.column_mapping.ColumnMapping] = None, engine: Optional[Type[evidently.calculation_engine.engine.Engine]] = None, additional_data: Dict[str, Any] = None, timestamp: Optional[datetime.datetime] = None) -> None
#  |
#  |  set_batch_size(self, batch_size: str)
#  |
#  |  set_dataset_id(self, dataset_id: str)
#  |
#  |  set_model_id(self, model_id: str)
#  |
#  |  set_reference_id(self, reference_id: str)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  __annotations__ = {'_columns_info': <class 'evidently.metric_results.D...
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from evidently.suite.base_suite.ReportBase:
#  |
#  |  datasets(self) -> evidently.calculation_engine.engine.EngineDatasets[typing.Any]
#  |
#  |  get_column_mapping(self) -> evidently.pipeline.column_mapping.ColumnMapping
#  |
#  |  has_descriptors(self) -> bool
#  |
#  |  save(self, filename) -> None
#  |      Save state to file (experimental)
#  |
#  |  to_snapshot(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from evidently.suite.base_suite.ReportBase:
#  |
#  |  load(filename) -> ~T from abc.ABCMeta
#  |      Load state from file (experimental)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from evidently.suite.base_suite.ReportBase:
#  |
#  |  metadata = {}
#  |
#  |  name = None
#  |
#  |  tags = []
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from evidently.suite.base_suite.Display:
#  |
#  |  get_html(self)
#  |
#  |  json(self, include_render: bool = False, include: Dict[str, Union[ForwardRef('AbstractSetIntStr'), ForwardRef('MappingIntStrAny')]] = None, exclude: Dict[str, Union[ForwardRef('AbstractSetIntStr'), ForwardRef('MappingIntStrAny')]] = None, **kwargs) -> str
#  |
#  |  save_html(self, filename: Union[str, IO], mode: Union[str, evidently.utils.dashboard.SaveMode] = <SaveMode.SINGLE_FILE: 'singlefile'>)
#  |
#  |  save_json(self, filename, include_render: bool = False, include: Dict[str, Union[ForwardRef('AbstractSetIntStr'), ForwardRef('MappingIntStrAny')]] = None, exclude: Dict[str, Union[ForwardRef('AbstractSetIntStr'), ForwardRef('MappingIntStrAny')]] = None)
#  |
#  |  show(self, mode='auto')
#  |      Keyword arguments:
#  |      `mode` - Deprecated.
#  |
#  |      Now you should call
#  |      this function without any args, like: `.show()`
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from evidently.suite.base_suite.Display:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
! pip install evidently
# Out:
# Requirement already satisfied: evidently in c:\users\risha\anaconda3\lib\site-packages (0.4.38)
# Requirement already satisfied: plotly>=5.10.0 in c:\users\risha\anaconda3\lib\site-packages (from evidently) (5.24.1)
# Requirement already satisfied: statsmodels>=0.12.2 in c:\users\risha\anaconda3\lib\site-packages (from evidently) (0.14.0)
# Requirement already satisfied: scikit-learn>=1.0.1 in c:\users\risha\anaconda3\lib\site-packages (from evidently) (1.2.2)
# Requirement already satisfied: pandas>=1.3.5 in c:\users\risha\anaconda3\lib\site-packages (from pandas[parquet]>=1.3.5->evidently) (2.1.4)
# Requirement already satisfied: numpy<2.1,>=1.22.0 in c:\users\risha\anaconda3\lib\site-packages (from evidently) (1.26.4)
# Requirement already satisfied: nltk>=3.6.7 in c:\users\risha\anaconda3\lib\site-packages (from evidently) (3.8.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\risha\anaconda3\lib\site-packages (from evidently) (1.11.4)
# Requirement already satisfied: requests>=2.32.0 in c:\users\risha\anaconda3\lib\site-packages (from evidently) (2.32.3)
# Requirement already satisfied: PyYAML>=5.4 in c:\users\risha\anaconda3\lib\site-packages (from evidently) (6.0.1)
# Requirement already satisfied: pydantic>=1.10.13 in c:\users\risha\anaconda3\lib\site-packages (from evidently) (2.9.2)
# Requirement already satisfied: litestar>=2.8.3 in c:\users\risha\anaconda3\lib\site-packages (from evidently) (2.12.1)
# Requirement already satisfied: typing-inspect>=0.9.0 in c:\users\risha\anaconda3\lib\site-packages (from evidently) (0.9.0)
# Requirement already satisfied: uvicorn>=0.22.0 in c:\users\risha\anaconda3\lib\site-packages (from uvicorn[standard]>=0.22.0->evidently) (0.32.0)
# Requirement already satisfied: watchdog>=3.0.0 in c:\users\risha\anaconda3\lib\site-packages (from evidently) (5.0.3)
# Requirement already satisfied: typer>=0.3 in c:\users\risha\anaconda3\lib\site-packages (from evidently) (0.12.5)
# Requirement already satisfied: rich>=13 in c:\users\risha\anaconda3\lib\site-packages (from evidently) (13.3.5)
# Requirement already satisfied: iterative-telemetry>=0.0.5 in c:\users\risha\anaconda3\lib\site-packages (from evidently) (0.0.9)
# Requirement already satisfied: dynaconf>=3.2.4 in c:\users\risha\anaconda3\lib\site-packages (from evidently) (3.2.6)
# Requirement already satisfied: certifi>=2024.7.4 in c:\users\risha\anaconda3\lib\site-packages (from evidently) (2024.8.30)
# Requirement already satisfied: urllib3>=1.26.19 in c:\users\risha\anaconda3\lib\site-packages (from evidently) (2.0.7)
# Requirement already satisfied: fsspec>=2024.6.1 in c:\users\risha\anaconda3\lib\site-packages (from evidently) (2024.9.0)
# Requirement already satisfied: ujson>=5.4.0 in c:\users\risha\anaconda3\lib\site-packages (from evidently) (5.4.0)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\risha\anaconda3\lib\site-packages (from evidently) (2.1.0)
# Requirement already satisfied: uuid6>=2024.7.10 in c:\users\risha\anaconda3\lib\site-packages (from evidently) (2024.7.10)
# Requirement already satisfied: cryptography>=43.0.1 in c:\users\risha\anaconda3\lib\site-packages (from evidently) (43.0.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\risha\anaconda3\lib\site-packages (from cryptography>=43.0.1->evidently) (1.16.0)
# Requirement already satisfied: packaging in c:\users\risha\anaconda3\lib\site-packages (from deprecation>=2.1.0->evidently) (23.1)
# Requirement already satisfied: appdirs in c:\users\risha\anaconda3\lib\site-packages (from iterative-telemetry>=0.0.5->evidently) (1.4.4)
# Requirement already satisfied: filelock in c:\users\risha\anaconda3\lib\site-packages (from iterative-telemetry>=0.0.5->evidently) (3.13.1)
# Requirement already satisfied: distro in c:\users\risha\anaconda3\lib\site-packages (from iterative-telemetry>=0.0.5->evidently) (1.8.0)
# Requirement already satisfied: anyio>=3 in c:\users\risha\anaconda3\lib\site-packages (from litestar>=2.8.3->evidently) (4.2.0)
# Requirement already satisfied: click in c:\users\risha\anaconda3\lib\site-packages (from litestar>=2.8.3->evidently) (8.1.7)
# Requirement already satisfied: httpx>=0.22 in c:\users\risha\anaconda3\lib\site-packages (from litestar>=2.8.3->evidently) (0.27.2)
# Requirement already satisfied: msgspec>=0.18.2 in c:\users\risha\anaconda3\lib\site-packages (from litestar>=2.8.3->evidently) (0.18.6)
# Requirement already satisfied: multidict>=6.0.2 in c:\users\risha\anaconda3\lib\site-packages (from litestar>=2.8.3->evidently) (6.0.4)
# Requirement already satisfied: polyfactory>=2.6.3 in c:\users\risha\anaconda3\lib\site-packages (from litestar>=2.8.3->evidently) (2.17.0)
# Requirement already satisfied: rich-click in c:\users\risha\anaconda3\lib\site-packages (from litestar>=2.8.3->evidently) (1.8.3)
# Requirement already satisfied: typing-extensions in c:\users\risha\anaconda3\lib\site-packages (from litestar>=2.8.3->evidently) (4.9.0)
# Requirement already satisfied: joblib in c:\users\risha\anaconda3\lib\site-packages (from nltk>=3.6.7->evidently) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\risha\anaconda3\lib\site-packages (from nltk>=3.6.7->evidently) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\risha\anaconda3\lib\site-packages (from nltk>=3.6.7->evidently) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\risha\anaconda3\lib\site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\risha\anaconda3\lib\site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\risha\anaconda3\lib\site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently) (2023.3)
# Requirement already satisfied: pyarrow>=7.0.0 in c:\users\risha\anaconda3\lib\site-packages (from pandas[parquet]>=1.3.5->evidently) (14.0.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\risha\anaconda3\lib\site-packages (from plotly>=5.10.0->evidently) (8.2.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\risha\anaconda3\lib\site-packages (from pydantic>=1.10.13->evidently) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\risha\anaconda3\lib\site-packages (from pydantic>=1.10.13->evidently) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\risha\anaconda3\lib\site-packages (from requests>=2.32.0->evidently) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\risha\anaconda3\lib\site-packages (from requests>=2.32.0->evidently) (3.4)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\risha\anaconda3\lib\site-packages (from rich>=13->evidently) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\risha\anaconda3\lib\site-packages (from rich>=13->evidently) (2.15.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\risha\anaconda3\lib\site-packages (from scikit-learn>=1.0.1->evidently) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\risha\anaconda3\lib\site-packages (from statsmodels>=0.12.2->evidently) (0.5.3)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\risha\anaconda3\lib\site-packages (from typer>=0.3->evidently) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\risha\anaconda3\lib\site-packages (from typing-inspect>=0.9.0->evidently) (1.0.0)
# Requirement already satisfied: h11>=0.8 in c:\users\risha\anaconda3\lib\site-packages (from uvicorn>=0.22.0->uvicorn[standard]>=0.22.0->evidently) (0.14.0)
# Requirement already satisfied: colorama>=0.4 in c:\users\risha\anaconda3\lib\site-packages (from uvicorn[standard]>=0.22.0->evidently) (0.4.6)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\risha\anaconda3\lib\site-packages (from uvicorn[standard]>=0.22.0->evidently) (0.6.2)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\risha\anaconda3\lib\site-packages (from uvicorn[standard]>=0.22.0->evidently) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\risha\anaconda3\lib\site-packages (from uvicorn[standard]>=0.22.0->evidently) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\risha\anaconda3\lib\site-packages (from uvicorn[standard]>=0.22.0->evidently) (13.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\risha\anaconda3\lib\site-packages (from anyio>=3->litestar>=2.8.3->evidently) (1.3.0)
# Requirement already satisfied: pycparser in c:\users\risha\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=43.0.1->evidently) (2.21)
# Requirement already satisfied: httpcore==1.* in c:\users\risha\anaconda3\lib\site-packages (from httpx>=0.22->litestar>=2.8.3->evidently) (1.0.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\risha\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=13->evidently) (0.1.0)
# Requirement already satisfied: six in c:\users\risha\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.12.2->evidently) (1.16.0)
# Requirement already satisfied: faker in c:\users\risha\anaconda3\lib\site-packages (from polyfactory>=2.6.3->litestar>=2.8.3->evidently) (30.4.0)
